# %%
import bs4
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="https://www.airlinequality.com/airline-reviews/british-airways"
response=requests.get(url)
response.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(response.text,'html5lib')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 9]>    <html class="no-js lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-GB">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    British Airways Customer Reviews - SKYTRAX
#   </title>
#   <!-- Google Chrome Frame for IE -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <!-- mobile meta -->
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <!-- icons & favicons -->
# ...

# %%
import re

# Extract the text within braces


print(countries_within_braces)
# Out:
# ['Belgium', 'Belgium', 'Canada', 'Denmark', 'United Kingdom', 'Australia', 'Canada', 'Singapore', 'United Kingdom', 'United Kingdom']

# %% [markdown]
# ## Scraping all pages

# %%
import time
import requests
from bs4 import BeautifulSoup

def ref_rev(base_url):
    pages = 1
    reviews = []
    dates = []
    country=[]

    for i in range(1, pages + 1):
        url = f"{base_url}/page/{i}"
        response = requests.get(url)
        data = response.text
        soup = BeautifulSoup(data, 'html5lib')

        h2_elements = soup.body.find_all('h2', class_="text_header")
        h3_elements = soup.find_all('time')
        h3_country = soup.find_all(class_="text_sub_header userStatusWrapper")
        for tag in h3_country:
            text = tag.get_text()
            country_match = re.search(r'\((.*?)\)', text)
            if country_match:
                country.append(country_match.group(1))
    


        h2_texts = [h2.text for h2 in h2_elements[0:10]]
        h3_texts = [h3.text for h3 in h3_elements[0:10]]

        reviews.extend(h2_texts)
        dates.extend(h3_texts)
    

    return dates, reviews,country

# %%
dates0,reviews0,country0= ref_rev("https://www.airlinequality.com/airline-reviews/british-airways")
dates1,reviews1,country1=ref_rev("https://www.airlinequality.com/airline-reviews/air-india")
dates2,reviews2,country2=ref_rev("https://www.airlinequality.com/airline-reviews/emirates")
dates3,reviews3,country3=ref_rev("https://www.airlinequality.com/airline-reviews/etihad-airways")
dates4,reviews4,country4=ref_rev("https://www.airlinequality.com/airline-reviews/qatar-airways")

# %%
country0
# Out:
# ['Belgium',
#  'Belgium',
#  'Canada',
#  'Denmark',
#  'United Kingdom',
#  'Australia',
#  'Canada',
#  'Singapore',
#  'United Kingdom',
#  'United Kingdom']

# %% [markdown]
# ### **Creating Dataframes for each Airline**

# %%
Set_={'Date':dates0,'Customer Review':reviews0,'Country':country0}
BA_reviews=pd.DataFrame(Set_)

Set_1={'Date':dates1,'Customer Review':reviews1,'Country':country1}
Air_Ind_reviews=pd.DataFrame(Set_1)

Set_2={'Date':dates2,'Customer Review':reviews2,'Country':country2}
Emirates_reviews=pd.DataFrame(Set_2)

Set_3={'Date':dates3,'Customer Review':reviews3,'Country':country3}
Ethihad_reviews=pd.DataFrame(Set_3)

Set_4={'Date':dates4,'Customer Review':reviews4,'Country':country4}
Qatar_reviews=pd.DataFrame(Set_4)

# %%
Emirates_reviews
# Out:
#                  Date                            Customer Review  \
# 0     13th March 2024           "will never recommend Emirates"
# 1     10th March 2024                 "Don’t book this airline!"
# 2      9th March 2024              "plenty of drinks available"
# 3      8th March 2024                   "check-in was very good"
# 4      4th March 2024          "certainly not a premium airline"
# 5      4th March 2024  "Qatar Airways really puts them to shame"
# 6      3rd March 2024      "Unacceptable treatment of customers"
# 7  28th February 2024             “the most terrible experience”
# 8  22nd February 2024                 "Do not fly with Emirates"
# 9  21st February 2024                "a very comfortable flight"
#
#           Country
# 0        Pakistan
# 1         Germany
# 2       Australia
# 3       Australia
# 4          Poland
# 5  United Kingdom
# 6          France
# 7   United States
# 8       Australia
# 9       Australia

# %% [markdown]
# ### **Fixing the Date Format**

# %%
def date_1(dat):
    dat["Dates"]=pd.to_datetime(dat["Date"],format='mixed')
    dat["Date"]=dat["Dates"]
    dat.drop(columns=["Dates"],inplace=True)
    return dat

data=[Air_Ind_reviews,BA_reviews,Emirates_reviews,Ethihad_reviews,Qatar_reviews]
for df in data:
    df=date_1(df)

# %%
Qatar_reviews
# Out:
#         Date                        Customer Review         Country
# 0 2024-03-13             "Will recommend to others"         Germany
# 1 2024-03-13         "just one meal on this flight"     Netherlands
# 2 2024-03-10    "given completely different seats"         Bulgaria
# 3 2024-03-09       "Very happy with Qatar Airways"           Sweden
# 4 2024-03-09       "Service and catering very good"         Germany
# 5 2024-03-02             “marred by inconveniences”  United Kingdom
# 6 2024-02-29                "seat wouldn't stay up"          Canada
# 7 2024-02-29  "no attempt to address our complaint"       Australia
# 8 2024-02-25          “I hope they update the A380”           Qatar
# 9 2024-02-22            "I’d rate them maybe 7/10"   United Kingdom

# %%
Qatar_reviews["Customer Review"].value_counts().sort_values(ascending=False)
# Out:
# Customer Review
# "Will recommend to others"               1
# "just one meal on this flight"           1
# "given completely different seats"       1
# "Very happy with Qatar Airways"          1
# "Service and catering very good"         1
# “marred by inconveniences”               1
# "seat wouldn't stay up"                  1
# "no attempt to address our complaint"    1
# “I hope they update the A380”            1
# "I’d rate them maybe 7/10"               1
# Name: count, dtype: int64

# %% [markdown]
# # NLP

# %%
import re
def clean(text):
    text = re.sub('[^A-Za-z]+', ' ', str(text))
    return text
    
# Cleaning the text in the review column
data=[Air_Ind_reviews,BA_reviews,Emirates_reviews,Ethihad_reviews,Qatar_reviews]
for df in data:
    df['Cleaned Reviews']=df['Customer Review'].apply(clean)

# %%
Qatar_reviews
# Out:
#         Date                        Customer Review         Country  \
# 0 2024-03-13             "Will recommend to others"         Germany
# 1 2024-03-13         "just one meal on this flight"     Netherlands
# 2 2024-03-10    "given completely different seats"         Bulgaria
# 3 2024-03-09       "Very happy with Qatar Airways"           Sweden
# 4 2024-03-09       "Service and catering very good"         Germany
# 5 2024-03-02             “marred by inconveniences”  United Kingdom
# 6 2024-02-29                "seat wouldn't stay up"          Canada
# 7 2024-02-29  "no attempt to address our complaint"       Australia
# 8 2024-02-25          “I hope they update the A380”           Qatar
# 9 2024-02-22            "I’d rate them maybe 7/10"   United Kingdom
#
#                          Cleaned Reviews
# 0              Will recommend to others
# 1          just one meal on this flight
# 2      given completely different seats
# 3         Very happy with Qatar Airways
# ...

# %%
import nltk

"""This punkt tokenizer divides a text into a list of sentences by using an unsupervised algorithm to build a model for abbreviation words, 
collocations, and words that start sentences. """

nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#The nltk.corpus package defines a collection of corpus reader classes, which can be used to access the contents of a diverse set of corpora.
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')

# POS tagger dictionary
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
          newlist.append(tuple([word, pos_dict.get(tag[0])]))
    return newlist 

for df in data:
    df['POS tagged']=df['Cleaned Reviews'].apply(token_stop_pos)
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
Qatar_reviews.head(6)
# Out:
#         Date                      Customer Review         Country  \
# 0 2024-03-13           "Will recommend to others"         Germany
# 1 2024-03-13       "just one meal on this flight"     Netherlands
# 2 2024-03-10  "given completely different seats"         Bulgaria
# 3 2024-03-09     "Very happy with Qatar Airways"           Sweden
# 4 2024-03-09     "Service and catering very good"         Germany
# 5 2024-03-02           “marred by inconveniences”  United Kingdom
#
#                       Cleaned Reviews  \
# 0           Will recommend to others
# 1       just one meal on this flight
# 2   given completely different seats
# 3      Very happy with Qatar Airways
# 4     Service and catering very good
# 5           marred by inconveniences
#
#                                           POS tagged
# 0                      [(recommend, v), (others, n)]
# 1              [(one, None), (meal, n), (flight, n)]
# 2  [(given, v), (completely, r), (different, a), ...
# ...

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
     if not pos:
        lemma = word
        lemma_rew = lemma_rew + " " + lemma
     else:
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        lemma_rew = lemma_rew + " " + lemma
    return lemma_rew

for df in data:
    df['Lemma']=df['POS tagged'].apply(lemmatize)
Emirates_reviews.head()
# Out:
#         Date                    Customer Review    Country  \
# 0 2024-03-13   "will never recommend Emirates"    Pakistan
# 1 2024-03-10         "Don’t book this airline!"    Germany
# 2 2024-03-09      "plenty of drinks available"   Australia
# 3 2024-03-08           "check-in was very good"  Australia
# 4 2024-03-04  "certainly not a premium airline"     Poland
#
#                      Cleaned Reviews  \
# 0     will never recommend Emirates
# 1           Don t book this airline
# 2        plenty of drinks available
# 3            check in was very good
# 4   certainly not a premium airline
#
#                                      POS tagged                        Lemma
# 0   [(never, r), (recommend, v), (Emirates, n)]     never recommend Emirates
# 1                     [(book, n), (airline, n)]                 book airline
# 2    [(plenty, n), (drinks, n), (available, a)]       plenty drink available
# 3                       [(check, n), (good, a)]                   check good
# ...

# %% [markdown]
# ## Analyze the Sentiment

# %%
# !pip install vaderSentiment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# function to calculate vader sentiment
def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']
for df in data:
    df['Sentiment'] = df['Lemma'].apply(vadersentimentanalysis)

# function to analyse
def vader_analysis(compound):
    if compound >= 0.4:
        return 'Positive'
    elif compound < 0 :
        return 'Negative'
    else:
        return 'Neutral'
for df in data:
    df['Analysis'] = df['Sentiment'].apply(vader_analysis)

# %%
Qatar_reviews
# Out:
#         Date                        Customer Review         Country  \
# 0 2024-03-13             "Will recommend to others"         Germany
# 1 2024-03-13         "just one meal on this flight"     Netherlands
# 2 2024-03-10    "given completely different seats"         Bulgaria
# 3 2024-03-09       "Very happy with Qatar Airways"           Sweden
# 4 2024-03-09       "Service and catering very good"         Germany
# 5 2024-03-02             “marred by inconveniences”  United Kingdom
# 6 2024-02-29                "seat wouldn't stay up"          Canada
# 7 2024-02-29  "no attempt to address our complaint"       Australia
# 8 2024-02-25          “I hope they update the A380”           Qatar
# 9 2024-02-22            "I’d rate them maybe 7/10"   United Kingdom
#
#                          Cleaned Reviews  \
# 0              Will recommend to others
# 1          just one meal on this flight
# 2      given completely different seats
# 3         Very happy with Qatar Airways
# ...

# %%
def rat(col):
    if(col=="Positive"):
        score=5
    elif (col=="Neutral"):
        score=2.5
    else:
        score=1
    return score

for df in data:
    df["Rating"]=df["Analysis"].apply(rat)
    
Qatar_reviews
# Out:
#         Date                        Customer Review         Country  \
# 0 2024-03-13             "Will recommend to others"         Germany
# 1 2024-03-13         "just one meal on this flight"     Netherlands
# 2 2024-03-10    "given completely different seats"         Bulgaria
# 3 2024-03-09       "Very happy with Qatar Airways"           Sweden
# 4 2024-03-09       "Service and catering very good"         Germany
# 5 2024-03-02             “marred by inconveniences”  United Kingdom
# 6 2024-02-29                "seat wouldn't stay up"          Canada
# 7 2024-02-29  "no attempt to address our complaint"       Australia
# 8 2024-02-25          “I hope they update the A380”           Qatar
# 9 2024-02-22            "I’d rate them maybe 7/10"   United Kingdom
#
#                          Cleaned Reviews  \
# 0              Will recommend to others
# 1          just one meal on this flight
# 2      given completely different seats
# 3         Very happy with Qatar Airways
# ...

# %%
Qatar_reviews["Analysis"].value_counts()
# Out:
# Analysis
# Neutral     5
# Positive    3
# Negative    2
# Name: count, dtype: int64

# %%
cols=["Date","Country","Customer Review", "Analysis", "Rating"]
Air_india_Rating=Air_Ind_reviews[cols]
BA_Rating=BA_reviews[cols]
Emirates_Rating=Emirates_reviews[cols]
Ethihad_Rating=Ethihad_reviews[cols]
Qatar_Rating=Qatar_reviews[cols]

# %%
Qatar_Rating
# Out:
#         Date         Country                        Customer Review  Analysis  \
# 0 2024-03-13         Germany             "Will recommend to others"   Neutral
# 1 2024-03-13     Netherlands         "just one meal on this flight"   Neutral
# 2 2024-03-10        Bulgaria    "given completely different seats"    Neutral
# 3 2024-03-09          Sweden       "Very happy with Qatar Airways"   Positive
# 4 2024-03-09         Germany       "Service and catering very good"  Positive
# 5 2024-03-02  United Kingdom             “marred by inconveniences”  Negative
# 6 2024-02-29          Canada                "seat wouldn't stay up"   Neutral
# 7 2024-02-29       Australia  "no attempt to address our complaint"  Negative
# 8 2024-02-25           Qatar          “I hope they update the A380”  Positive
# 9 2024-02-22  United Kingdom            "I’d rate them maybe 7/10"    Neutral
#
#    Rating
# 0     2.5
# 1     2.5
# 2     2.5
# 3     5.0
# 4     5.0
# 5     1.0
# 6     2.5
# 7     1.0
# ...

# %% [markdown]
# ### Data Warehousing
#
# **Data is already saved in CSV format**

# %%
Air_india_Rating=pd.read_csv("C:\\Users\\varun\\OneDrive\\Desktop\\6th Sem\\Sentiment Analysis\\Air_Ind_Ratings.csv")
BA_Rating=pd.read_csv("C:\\Users\\varun\\OneDrive\\Desktop\\6th Sem\\Sentiment Analysis\\BA_Ratings.csv")
Emirates_Rating=pd.read_csv("C:\\Users\\varun\\OneDrive\\Desktop\\6th Sem\\Sentiment Analysis\\Emirates_Ratings.csv")
Ethihad_Rating=pd.read_csv("C:\\Users\\varun\\OneDrive\\Desktop\\6th Sem\\Sentiment Analysis\\Ethihad_Ratings.csv")
Qatar_Rating=pd.read_csv("C:\\Users\\varun\\OneDrive\\Desktop\\6th Sem\\Sentiment Analysis\\Qatar_Ratings.csv")

# %%
import mysql.connector
coxn = mysql.connector.connect(user='root', password='avin_123',
                              host='127.0.0.1',
                              database='reviews')

# %%
from sqlalchemy import create_engine
coxn = mysql.connector.connect(user='root', password='avin_123', host='127.0.0.1', database='reviews')
# Create a SQLAlchemy engine from the MySQL connection
pas = 'avin_123'
engine = create_engine(f"mysql+mysqlconnector://root:{pas}@127.0.0.1:3306/reviews", connect_args={'auth_plugin': 'mysql_native_password'})

# %%
Air_india_Rating.to_sql("Air India",engine,if_exists='replace',method='multi')
BA_Rating.to_sql("British Airways",engine,if_exists='replace',method='multi')
Emirates_Rating.to_sql("Emirates",engine,if_exists='replace',method='multi')
Ethihad_Rating.to_sql("Ethihad",engine,if_exists='replace',method='multi')
Qatar_Rating.to_sql("Qatar",engine,if_exists='replace',method='multi')
# Out:
# C:\Users\varun\AppData\Local\Temp\ipykernel_27520\143959530.py:1: UserWarning: The provided table name 'Air India' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Air_india_Rating.to_sql("Air India",engine,if_exists='replace',method='multi')
# C:\Users\varun\AppData\Local\Temp\ipykernel_27520\143959530.py:2: UserWarning: The provided table name 'British Airways' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   BA_Rating.to_sql("British Airways",engine,if_exists='replace',method='multi')
# C:\Users\varun\AppData\Local\Temp\ipykernel_27520\143959530.py:3: UserWarning: The provided table name 'Emirates' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
# ...
